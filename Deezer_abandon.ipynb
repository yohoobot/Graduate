# %% [markdown]
# <a href="https://colab.research.google.com/github/yohoobot/works/blob/main/Deezer_abandon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""
Deezer餐馆场景音乐爬虫：构建"场景描述" - "背景音乐描述"训练样本
新方案：使用 Deezer API 搜索播放列表，下载预览音频并提取详细特征。
无需认证，兼容 Colab/Jupyter。
"""

import requests
import pandas as pd
import time
import os

# ========== 1. 构建关键词列表 ==========
KEYWORDS = [
    "restaurant", "cafe", "coffee shop", "dining",
    "brunch spot", "fine dining", "bistro", "bar",
    "japanese restaurant", "sushi bar", "izakaya",
    "chinese restaurant", "hotpot", "dim sum",
    "korean bbq", "french restaurant", "italian restaurant",
    "mexican restaurant", "indian restaurant", "vegan cafe"
]

# ========== 2. 初始化数据集 & 音频保存文件夹 ==========
data_pairs = []
os.makedirs("preview_audio", exist_ok=True)

# ========== 3. 预先抓取 genre 对照表 ==========
genre_map = {}
genre_resp = requests.get("https://api.deezer.com/genre")
if genre_resp.status_code == 200:
    genre_data = genre_resp.json().get("data", [])
    genre_map = {item["id"]: item["name"] for item in genre_data}

# ========== 4. 遍历关键词，使用 Deezer API 搜索播放列表并提取曲目 ==========
for keyword in KEYWORDS:
    print(f"🔍 正在搜索关键词：{keyword}")
    playlist_search_url = f"https://api.deezer.com/search/playlist?q={keyword}"
    resp = requests.get(playlist_search_url)
    if resp.status_code != 200:
        print(f"⚠️ 播放列表搜索失败：{playlist_search_url}")
        continue

    search_data = resp.json()
    playlists = search_data.get("data", [])
    print(f"📊 找到播放列表数：{len(playlists)}")

    if not playlists:
        print("❌ 没有找到相关播放列表。")
        continue

    for pl in playlists[:3]:  # 每个关键词取前3个播放列表
        playlist_id = pl.get("id")
        playlist_title = pl.get("title")
        playlist_desc = pl.get("description", "")
        print(f"🎵 正在抓取播放列表：{playlist_title}")

        playlist_url = f"https://api.deezer.com/playlist/{playlist_id}"
        playlist_resp = requests.get(playlist_url)
        if playlist_resp.status_code != 200:
            print(f"⚠️ 歌单获取失败：{playlist_url}")
            continue

        playlist_data = playlist_resp.json()
        tracks = playlist_data.get("tracks", {}).get("data", [])
        if not tracks:
            print(f"⚠️ 播放列表无曲目：{playlist_title}")
            continue

        for item in tracks[:5]:  # 每个播放列表取前5首歌
            track_id = item.get("id")
            track_title = item.get("title")
            artist_name = item.get("artist", {}).get("name")
            preview_url = item.get("preview")
            album_title = item.get("album", {}).get("title")
            track_link = item.get("link")

            # 请求 track 详情以获取 bpm、gain、genre 等
            detail_url = f"https://api.deezer.com/track/{track_id}"
            detail_resp = requests.get(detail_url)
            if detail_resp.status_code != 200:
                print(f"⚠️ 获取详情失败：{detail_url}")
                continue

            detail = detail_resp.json()
            bpm = detail.get("bpm")
            gain = detail.get("gain")
            genre_id = detail.get("genre_id")
            genre_name = genre_map.get(genre_id, "unknown")

            if not preview_url:
                print(f"⚠️ 无试听链接：{track_title}")
                continue

            # 下载预览音频
            try:
                audio_data = requests.get(preview_url).content
                filename = f"preview_audio/{track_id}.mp3"
                with open(filename, "wb") as f:
                    f.write(audio_data)
                print(f"🎧 预览音频已保存：{filename}")
            except Exception as e:
                print(f"⚠️ 下载失败：{preview_url}")
                continue

            scene_desc = f"Music from playlist '{playlist_title}' (keyword: '{keyword}'). Description: {playlist_desc}"
            music_info = {
                "track_id": track_id,
                "track_title": track_title,
                "artist": artist_name,
                "deezer_link": track_link,
                "bpm": bpm,
                "gain": gain,
                "genre": genre_name,
                "preview_path": filename
            }
            data_pairs.append({"scene": scene_desc.strip(), **music_info})
            time.sleep(1)  # 请休息 1 秒，避免请求过快

# ========== 5. 保存为CSV ==========
df = pd.DataFrame(data_pairs)
df.to_csv("scene_music_pairs.csv", index=False, encoding="utf-8-sig")
print("✅ 数据抓取完成，保存为 scene_music_pairs.csv")
# Out:
# 🔍 正在搜索关键词：restaurant
# 📊 找到播放列表数：25
# 🎵 正在抓取播放列表：Restaurant Background Music 🍸 chill covers
# 🎧 预览音频已保存：preview_audio/3070104201.mp3
# 🎧 预览音频已保存：preview_audio/2893242971.mp3
# 🎧 预览音频已保存：preview_audio/128156069.mp3
# 🎧 预览音频已保存：preview_audio/3149220331.mp3
# 🎧 预览音频已保存：preview_audio/2898482391.mp3
# 🎵 正在抓取播放列表：Dinner Lounge 🍸 Cocktail Bar, Restaurant, Café
# 🎧 预览音频已保存：preview_audio/2893242971.mp3
# 🎧 预览音频已保存：preview_audio/3070104201.mp3
# 🎧 预览音频已保存：preview_audio/3149220331.mp3
# 🎧 预览音频已保存：preview_audio/2715671332.mp3
# 🎧 预览音频已保存：preview_audio/2934415641.mp3
# 🎵 正在抓取播放列表：Restaurant Bossa Nova : lounge, apéro bossanova
# 🎧 预览音频已保存：preview_audio/1161654902.mp3
# 🎧 预览音频已保存：preview_audio/716910742.mp3
# 🎧 预览音频已保存：preview_audio/2294518895.mp3
# 🎧 预览音频已保存：preview_audio/1228436532.mp3
# 🎧 预览音频已保存：preview_audio/964492122.mp3
# 🔍 正在搜索关键词：cafe
# 📊 找到播放列表数：25
# 🎵 正在抓取播放列表：Café Lounge ☕️ Coffee Chill Covers, Koffie, Kaffee
# 🎧 预览音频已保存：preview_audio/2873362382.mp3
# 🎧 预览音频已保存：preview_audio/3070104201.mp3
# 🎧 预览音频已保存：preview_audio/3130358391.mp3
# 🎧 预览音频已保存：preview_audio/3106841701.mp3
# 🎧 预览音频已保存：preview_audio/128156069.mp3
# 🎵 正在抓取播放列表：The Indie Café
# 🎧 预览音频已保存：preview_audio/2294588675.mp3
# ⚠️ 无试听链接：Golden Mirror
# 🎧 预览音频已保存：preview_audio/2515514491.mp3
# 🎧 预览音频已保存：preview_audio/1091843082.mp3
# ⚠️ 无试听链接：Unholy Appetite
# 🎵 正在抓取播放列表：Dinner Lounge 🍸 Cocktail Bar, Restaurant, Café
# 🎧 预览音频已保存：preview_audio/2893242971.mp3
# 🎧 预览音频已保存：preview_audio/3070104201.mp3
# 🎧 预览音频已保存：preview_audio/3149220331.mp3
# 🎧 预览音频已保存：preview_audio/2715671332.mp3
# 🎧 预览音频已保存：preview_audio/2934415641.mp3
# 🔍 正在搜索关键词：coffee shop
# 📊 找到播放列表数：25
# 🎵 正在抓取播放列表：Chill Country - Coffee Shop Vibes
# 🎧 预览音频已保存：preview_audio/3042275231.mp3
# 🎧 预览音频已保存：preview_audio/3200905201.mp3
# 🎧 预览音频已保存：preview_audio/2635986612.mp3
# 🎧 预览音频已保存：preview_audio/2999575511.mp3
# 🎧 预览音频已保存：preview_audio/3161283401.mp3
# 🎵 正在抓取播放列表：#Fox Coffee Shop Metz
# ⚠️ 无试听链接：Sharpness
# 🎧 预览音频已保存：preview_audio/67929287.mp3
# 🎧 预览音频已保存：preview_audio/5087067.mp3
# ⚠️ 无试听链接：Matilda
# ⚠️ 无试听链接：Valerie (Live, BBC Radio 1 Live Lounge, London/2007)
# 🎵 正在抓取播放列表：Lofi Coffee Shop (Lo-Fi Café Morning)
# 🎧 预览音频已保存：preview_audio/2073230917.mp3
# 🎧 预览音频已保存：preview_audio/2410784205.mp3
# 🎧 预览音频已保存：preview_audio/2037354087.mp3
# 🎧 预览音频已保存：preview_audio/2424400685.mp3
# 🎧 预览音频已保存：preview_audio/2407672745.mp3
# 🔍 正在搜索关键词：dining
# 📊 找到播放列表数：25
# 🎵 正在抓取播放列表：metal detector
# 🎧 预览音频已保存：preview_audio/3241996351.mp3
# 🎧 预览音频已保存：preview_audio/3211005751.mp3
# 🎧 预览音频已保存：preview_audio/3240886301.mp3
# 🎧 预览音频已保存：preview_audio/3140999431.mp3
# 🎧 预览音频已保存：preview_audio/2911987101.mp3
# 🎵 正在抓取播放列表：Soundcheck
# 🎧 预览音频已保存：preview_audio/3134470271.mp3
# 🎧 预览音频已保存：preview_audio/3257138251.mp3
# 🎧 预览音频已保存：preview_audio/3266945511.mp3
# 🎧 预览音频已保存：preview_audio/3231988511.mp3
# 🎧 预览音频已保存：preview_audio/3268687721.mp3
# 🎵 正在抓取播放列表：Fine Dining Music
# 🎧 预览音频已保存：preview_audio/1147187622.mp3
# 🎧 预览音频已保存：preview_audio/1232887922.mp3
# 🎧 预览音频已保存：preview_audio/1357727972.mp3
# 🎧 预览音频已保存：preview_audio/803999012.mp3
# 🎧 预览音频已保存：preview_audio/1771424047.mp3
# 🔍 正在搜索关键词：brunch spot
# 📊 找到播放列表数：1
# 🎵 正在抓取播放列表：Sport & Leisure Brunch
# 🎧 预览音频已保存：preview_audio/516351522.mp3
# 🎧 预览音频已保存：preview_audio/78383508.mp3
# ⚠️ 无试听链接：Animal (Album Version)
# 🎧 预览音频已保存：preview_audio/970592.mp3
# 🎧 预览音频已保存：preview_audio/3851850.mp3
# 🔍 正在搜索关键词：fine dining
# 📊 找到播放列表数：25
# 🎵 正在抓取播放列表：Fine Dining Music
# 🎧 预览音频已保存：preview_audio/1147187622.mp3
# 🎧 预览音频已保存：preview_audio/1232887922.mp3
# 🎧 预览音频已保存：preview_audio/1357727972.mp3
# 🎧 预览音频已保存：preview_audio/803999012.mp3
# 🎧 预览音频已保存：preview_audio/1771424047.mp3
# 🎵 正在抓取播放列表：Play list restau soir
# 🎧 预览音频已保存：preview_audio/823533262.mp3
# 🎧 预览音频已保存：preview_audio/1003068372.mp3
# 🎧 预览音频已保存：preview_audio/1003068362.mp3
# 🎧 预览音频已保存：preview_audio/1003068442.mp3
# 🎧 预览音频已保存：preview_audio/1308170852.mp3
# 🎵 正在抓取播放列表：Instrumental Dinner Jazz
# 🎧 预览音频已保存：preview_audio/1222313142.mp3
# 🎧 预览音频已保存：preview_audio/1222313152.mp3
# 🎧 预览音频已保存：preview_audio/1222313162.mp3
# 🎧 预览音频已保存：preview_audio/1222313172.mp3
# 🎧 预览音频已保存：preview_audio/1222313182.mp3
# 🔍 正在搜索关键词：bistro
# 📊 找到播放列表数：25
# 🎵 正在抓取播放列表：bistrot
# ⚠️ 歌单获取失败：https://api.deezer.com/playlist/4616611884
# 🎵 正在抓取播放列表：Bistro
# ⚠️ 无试听链接：Price Tag (Acoustic Version) [Jessie J Cover]
# ⚠️ 无试听链接：Let Her Go (Acoustic Lounge) [Passenger Cover]
# 🎧 预览音频已保存：preview_audio/118306098.mp3
# ⚠️ 无试听链接：Devil May Cry (Acoustic Version) [The Weeknd Cover]
# 🎧 预览音频已保存：preview_audio/118306110.mp3
# 🎵 正在抓取播放列表：bistro
# ⚠️ 歌单获取失败：https://api.deezer.com/playlist/5176420024
# 🔍 正在搜索关键词：bar
# 📊 找到播放列表数：25
# 🎵 正在抓取播放列表：Piano Bar
# 🎧 预览音频已保存：preview_audio/2015051537.mp3
# 🎧 预览音频已保存：preview_audio/2111861627.mp3
# 🎧 预览音频已保存：preview_audio/3124606.mp3
# 🎧 预览音频已保存：preview_audio/606129202.mp3
# 🎧 预览音频已保存：preview_audio/1522739122.mp3
# 🎵 正在抓取播放列表：Dinner Lounge 🍸 Cocktail Bar, Restaurant, Café
# 🎧 预览音频已保存：preview_audio/2893242971.mp3
# 🎧 预览音频已保存：preview_audio/3070104201.mp3
# 🎧 预览音频已保存：preview_audio/3149220331.mp3
# 🎧 预览音频已保存：preview_audio/2715671332.mp3
# 🎧 预览音频已保存：preview_audio/2934415641.mp3
# 🎵 正在抓取播放列表：Surf Bar
# 🎧 预览音频已保存：preview_audio/71647298.mp3
# 🎧 预览音频已保存：preview_audio/1799708917.mp3
# 🎧 预览音频已保存：preview_audio/1367073362.mp3
# 🎧 预览音频已保存：preview_audio/608263342.mp3
# 🎧 预览音频已保存：preview_audio/3171905951.mp3
# 🔍 正在搜索关键词：japanese restaurant
# 📊 找到播放列表数：7
# 🎵 正在抓取播放列表：restaurant
# 🎧 预览音频已保存：preview_audio/2403410295.mp3
# 🎧 预览音频已保存：preview_audio/2403410305.mp3
# 🎧 预览音频已保存：preview_audio/2403410315.mp3
# 🎧 预览音频已保存：preview_audio/2403410325.mp3
# 🎧 预览音频已保存：preview_audio/2403410335.mp3
# 🎵 正在抓取播放列表：KOI - Restaurante Sushi
# 🎧 预览音频已保存：preview_audio/3074038581.mp3
# 🎧 预览音频已保存：preview_audio/3059784741.mp3
# 🎧 预览音频已保存：preview_audio/756109402.mp3
# 🎧 预览音频已保存：preview_audio/3059784761.mp3
# 🎧 预览音频已保存：preview_audio/3059784751.mp3
# 🎵 正在抓取播放列表：Japanese Restaurant Music
# 🎧 预览音频已保存：preview_audio/23086201.mp3
# 🎧 预览音频已保存：preview_audio/22971411.mp3
# 🎧 预览音频已保存：preview_audio/22971251.mp3
# 🎧 预览音频已保存：preview_audio/22971221.mp3
# 🎧 预览音频已保存：preview_audio/22971241.mp3
# 🔍 正在搜索关键词：sushi bar
# 📊 找到播放列表数：25
# 🎵 正在抓取播放列表：Sr.Miyagi Sushi Bar Cartagena de Indias
# ⚠️ 歌单获取失败：https://api.deezer.com/playlist/7941918022
# 🎵 正在抓取播放列表：A - Sushi Bar Ô Buddha Bar •¸♫•♫˚ღ҉
# 🎧 预览音频已保存：preview_audio/94780984.mp3
# 🎧 预览音频已保存：preview_audio/70561622.mp3
# 🎧 预览音频已保存：preview_audio/67487240.mp3
# 🎧 预览音频已保存：preview_audio/66720941.mp3
# 🎧 预览音频已保存：preview_audio/135128338.mp3
# 🎵 正在抓取播放列表：sexy sushis
# 🎧 预览音频已保存：preview_audio/2856987282.mp3
# 🎧 预览音频已保存：preview_audio/2856987292.mp3
# 🎧 预览音频已保存：preview_audio/2856987302.mp3
# 🎧 预览音频已保存：preview_audio/2856987312.mp3
# 🎧 预览音频已保存：preview_audio/2856987322.mp3
# 🔍 正在搜索关键词：izakaya
# 📊 找到播放列表数：24
# 🎵 正在抓取播放列表：Japanese Izakaya Sake Bar
# 🎧 预览音频已保存：preview_audio/1646257222.mp3
# 🎧 预览音频已保存：preview_audio/2521563271.mp3
# 🎧 预览音频已保存：preview_audio/460133562.mp3
# 🎧 预览音频已保存：preview_audio/642023292.mp3
# 🎧 预览音频已保存：preview_audio/88886139.mp3
# 🎵 正在抓取播放列表：izakaya 03/11
# 🎧 预览音频已保存：preview_audio/884370.mp3
# 🎧 预览音频已保存：preview_audio/797434.mp3
# 🎧 预览音频已保存：preview_audio/105426364.mp3
# 🎧 预览音频已保存：preview_audio/3095197.mp3
# 🎧 预览音频已保存：preview_audio/3880509.mp3
# 🎵 正在抓取播放列表：izakaya kyotan
# 🎧 预览音频已保存：preview_audio/976040302.mp3
# 🎧 预览音频已保存：preview_audio/2345664365.mp3
# 🎧 预览音频已保存：preview_audio/1024987462.mp3
# 🎧 预览音频已保存：preview_audio/976020892.mp3
# 🎧 预览音频已保存：preview_audio/1024973872.mp3
# 🔍 正在搜索关键词：chinese restaurant
# 📊 找到播放列表数：21
# 🎵 正在抓取播放列表：Chinese restaurant
# 🎧 预览音频已保存：preview_audio/2193985487.mp3
# 🎧 预览音频已保存：preview_audio/69818406.mp3
# 🎧 预览音频已保存：preview_audio/1089807.mp3
# ⚠️ 无试听链接：Câu Chuyện Đầu Năm
# ⚠️ 无试听链接：Duyên Phận
# 🎵 正在抓取播放列表：Chinese Restaurant Music — Discover Asian Music, V
# ⚠️ 无试听链接：Return to Simplicity
# 🎧 预览音频已保存：preview_audio/17592541.mp3
# ⚠️ 无试听链接：Calling Out of Time
# ⚠️ 无试听链接：Waving Good-Bye
# ⚠️ 无试听链接：The Yin and Yang in Harmony
# 🎵 正在抓取播放列表：!! Chinese Restaurant !!
# 🎧 预览音频已保存：preview_audio/977920152.mp3
# 🎧 预览音频已保存：preview_audio/977920162.mp3
# 🎧 预览音频已保存：preview_audio/977920172.mp3
# 🎧 预览音频已保存：preview_audio/977920182.mp3
# 🎧 预览音频已保存：preview_audio/977920192.mp3
# 🔍 正在搜索关键词：hotpot
# 📊 找到播放列表数：25
# 🎵 正在抓取播放列表：top MPB
# 🎧 预览音频已保存：preview_audio/13207411.mp3
# 🎧 预览音频已保存：preview_audio/13231220.mp3
# 🎧 预览音频已保存：preview_audio/13231219.mp3
# 🎧 预览音频已保存：preview_audio/13239094.mp3
# 🎧 预览音频已保存：preview_audio/71395450.mp3
# 🎵 正在抓取播放列表：Jp - hotpots
# 🎧 预览音频已保存：preview_audio/13001554.mp3
# 🎧 预览音频已保存：preview_audio/13001555.mp3
# 🎧 预览音频已保存：preview_audio/13001556.mp3
# 🎧 预览音频已保存：preview_audio/13001558.mp3
# 🎧 预览音频已保存：preview_audio/13001561.mp3
# 🎵 正在抓取播放列表：Lancashire Hotpots
# 🎧 预览音频已保存：preview_audio/79505274.mp3
# 🎧 预览音频已保存：preview_audio/79505288.mp3
# 🎧 预览音频已保存：preview_audio/635445872.mp3
# 🎧 预览音频已保存：preview_audio/79505270.mp3
# 🎧 预览音频已保存：preview_audio/79505278.mp3
# 🔍 正在搜索关键词：dim sum
# 📊 找到播放列表数：25
# 🎵 正在抓取播放列表：films 🎬
# ⚠️ 无试听链接：Fever
# 🎧 预览音频已保存：preview_audio/78011460.mp3
# 🎧 预览音频已保存：preview_audio/141220925.mp3
# ⚠️ 无试听链接：Elara (Original Mix)
# 🎧 预览音频已保存：preview_audio/2183927187.mp3
# 🎵 正在抓取播放列表：dim sum 3
# 🎧 预览音频已保存：preview_audio/751337412.mp3
# 🎧 预览音频已保存：preview_audio/354347471.mp3
# ⚠️ 无试听链接：Leaves
# 🎧 预览音频已保存：preview_audio/937351902.mp3
# ⚠️ 无试听链接：Two Fish and an Elephant
# 🎵 正在抓取播放列表：Electro-pop 21
# 🎧 预览音频已保存：preview_audio/404344752.mp3
# 🎧 预览音频已保存：preview_audio/404344732.mp3
# 🎧 预览音频已保存：preview_audio/403074632.mp3
# 🎧 预览音频已保存：preview_audio/402689202.mp3
# 🎧 预览音频已保存：preview_audio/410960212.mp3
# 🔍 正在搜索关键词：korean bbq
# 📊 找到播放列表数：1
# 🎵 正在抓取播放列表：KOREAN BBQ BEEF
# ⚠️ 无试听链接：10 Years
# 🎧 预览音频已保存：preview_audio/741166612.mp3
# 🎧 预览音频已保存：preview_audio/1190326.mp3
# 🎧 预览音频已保存：preview_audio/1073119822.mp3
# 🎧 预览音频已保存：preview_audio/906588.mp3
# 🔍 正在搜索关键词：french restaurant
# 📊 找到播放列表数：25
# 🎵 正在抓取播放列表：Bistro Mix - Anzette Cloete
# 🎧 预览音频已保存：preview_audio/1188531622.mp3
# 🎧 预览音频已保存：preview_audio/1188531632.mp3
# 🎧 预览音频已保存：preview_audio/1188531642.mp3
# 🎧 预览音频已保存：preview_audio/1188531652.mp3
# 🎧 预览音频已保存：preview_audio/1188531662.mp3
# 🎵 正在抓取播放列表：Morning - French music for Restaurant Kompot
# 🎧 预览音频已保存：preview_audio/546875592.mp3
# ⚠️ 无试听链接：Les bruits de la ville
# 🎧 预览音频已保存：preview_audio/552624172.mp3
# ⚠️ 无试听链接：Pitou
# 🎧 预览音频已保存：preview_audio/601725092.mp3
# 🎵 正在抓取播放列表：Jazz
# 🎧 预览音频已保存：preview_audio/1062623342.mp3
# 🎧 预览音频已保存：preview_audio/1062623352.mp3
# 🎧 预览音频已保存：preview_audio/1062623362.mp3
# 🎧 预览音频已保存：preview_audio/1062623372.mp3
# 🎧 预览音频已保存：preview_audio/1062623382.mp3
# 🔍 正在搜索关键词：italian restaurant
# 📊 找到播放列表数：25
# 🎵 正在抓取播放列表：Italien restaurant
# 🎧 预览音频已保存：preview_audio/3295964.mp3
# 🎧 预览音频已保存：preview_audio/104731108.mp3
# 🎧 预览音频已保存：preview_audio/10180259.mp3
# 🎧 预览音频已保存：preview_audio/1005379.mp3
# 🎧 预览音频已保存：preview_audio/86016595.mp3
# 🎵 正在抓取播放列表：Italian classic restaurant café bar music
# ⚠️ 无试听链接：Il cielo in una stanza
# ⚠️ 无试听链接：24 000 baci
# 🎧 预览音频已保存：preview_audio/690256.mp3
# 🎧 预览音频已保存：preview_audio/999344.mp3
# 🎧 预览音频已保存：preview_audio/690376.mp3
# 🎵 正在抓取播放列表：Italian Restaurant Chill Music  - Musica Italiana
# 🎧 预览音频已保存：preview_audio/70460131.mp3
# 🎧 预览音频已保存：preview_audio/1500626722.mp3
# 🎧 预览音频已保存：preview_audio/1619576172.mp3
# 🎧 预览音频已保存：preview_audio/1004447082.mp3
# 🎧 预览音频已保存：preview_audio/1603355592.mp3
# 🔍 正在搜索关键词：mexican restaurant
# 📊 找到播放列表数：25
# 🎵 正在抓取播放列表：Mexican Restaurant
# ⚠️ 无试听链接：No Vale la Pena
# ⚠️ 无试听链接：Cielito Lindo
# ⚠️ 无试听链接：Ya Viene Amaneciendo
# 🎧 预览音频已保存：preview_audio/455561892.mp3
# 🎧 预览音频已保存：preview_audio/2820793.mp3
# 🎵 正在抓取播放列表：Música para restaurantes 2022 //Mexican Restaurant
# ⚠️ 无试听链接：No Vale la Pena
# ⚠️ 无试听链接：Cielito Lindo
# ⚠️ 无试听链接：Ya Viene Amaneciendo
# 🎧 预览音频已保存：preview_audio/455561892.mp3
# 🎧 预览音频已保存：preview_audio/2820793.mp3
# 🎵 正在抓取播放列表：musica restaurant O mexicain
# 🎧 预览音频已保存：preview_audio/1569878292.mp3
# 🎧 预览音频已保存：preview_audio/1085148962.mp3
# 🎧 预览音频已保存：preview_audio/424284102.mp3
# 🎧 预览音频已保存：preview_audio/77949575.mp3
# 🎧 预览音频已保存：preview_audio/618619962.mp3
# 🔍 正在搜索关键词：indian restaurant
# 📊 找到播放列表数：23
# 🎵 正在抓取播放列表：Indian Restaurant
# 🎧 预览音频已保存：preview_audio/16700865.mp3
# 🎧 预览音频已保存：preview_audio/16700866.mp3
# 🎧 预览音频已保存：preview_audio/16700867.mp3
# 🎧 预览音频已保存：preview_audio/16700868.mp3
# 🎧 预览音频已保存：preview_audio/16700869.mp3
# 🎵 正在抓取播放列表：Massage
# 🎧 预览音频已保存：preview_audio/500489512.mp3
# 🎧 预览音频已保存：preview_audio/500489522.mp3
# 🎧 预览音频已保存：preview_audio/500489562.mp3
# 🎧 预览音频已保存：preview_audio/500489572.mp3
# 🎧 预览音频已保存：preview_audio/500489602.mp3
# 🎵 正在抓取播放列表：Indian Restaurant Music
# 🎧 预览音频已保存：preview_audio/855061332.mp3
# 🎧 预览音频已保存：preview_audio/855061342.mp3
# 🎧 预览音频已保存：preview_audio/855061352.mp3
# 🎧 预览音频已保存：preview_audio/855061362.mp3
# 🎧 预览音频已保存：preview_audio/855061372.mp3
# 🔍 正在搜索关键词：vegan cafe
# 📊 找到播放列表数：9
# 🎵 正在抓取播放列表：Lounge Mix 2020 | Deep House | Café Del Mar |Chill Bar |Ibiza Lounge | Regard - Ride It | Surf Mesa
# 🎧 预览音频已保存：preview_audio/768673982.mp3
# 🎧 预览音频已保存：preview_audio/886766742.mp3
# 🎧 预览音频已保存：preview_audio/1008012962.mp3
# 🎧 预览音频已保存：preview_audio/863517342.mp3
# 🎧 预览音频已保存：preview_audio/136889434.mp3
# 🎵 正在抓取播放列表：bpm > 132 bpm
# 🎧 预览音频已保存：preview_audio/2996994321.mp3
# 🎧 预览音频已保存：preview_audio/550165412.mp3
# 🎧 预览音频已保存：preview_audio/1341228392.mp3
# 🎧 预览音频已保存：preview_audio/62083052.mp3
# 🎧 预览音频已保存：preview_audio/1802244617.mp3
# 🎵 正在抓取播放列表：Cafe Del Mar 2016 - Dimitri Vegas
# 🎧 预览音频已保存：preview_audio/124549694.mp3
# ✅ 数据抓取完成，保存为 scene_music_pairs.csv
