# %% [markdown]
# <a href="https://colab.research.google.com/github/yohoobot/works/blob/main/spt3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""
Spotify餐馆场景音乐爬虫（使用 Client Credentials Flow 获取 token）：
根据关键词搜索含描述的公开歌单，并提取歌单与曲目信息。
"""

import requests
import pandas as pd
import time
import base64

# ========== 1. 设置 Spotify 开发者凭据 ==========
CLIENT_ID = ""
CLIENT_SECRET = ""


# ========== 2. 获取 Access Token ==========
def get_access_token(client_id, client_secret):
    auth_str = f"{client_id}:{client_secret}"
    b64_auth = base64.b64encode(auth_str.encode()).decode()

    headers = {
        "Authorization": f"Basic {b64_auth}",
        "Content-Type": "application/x-www-form-urlencoded"
    }
    data = {
        "grant_type": "client_credentials"
    }
    resp = requests.post("https://accounts.spotify.com/api/token", headers=headers, data=data)
    if resp.status_code == 200:
        return resp.json().get("access_token")
    else:
        print("❌ 无法获取 access_token")
        print(resp.text)
        return None

ACCESS_TOKEN = get_access_token(CLIENT_ID, CLIENT_SECRET)
if not ACCESS_TOKEN:
    raise RuntimeError("无法获取 access_token，终止程序。")

HEADERS = {"Authorization": f"Bearer {ACCESS_TOKEN}"}

# ========== 3. 构建关键词列表 ==========
KEYWORDS = [
    "restaurant", "cafe", "coffee shop", "dining",
    "brunch spot", "fine dining", "bistro", "bar",
    "japanese restaurant", "sushi bar", "izakaya",
    "chinese restaurant", "hotpot", "dim sum",
    "korean bbq", "french restaurant", "italian restaurant",
    "mexican restaurant", "indian restaurant", "vegan cafe"
]

# ========== 4. 初始化结果列表 ==========
data_pairs = []

# ========== 5. 遍历关键词，搜索播放列表 ==========
for keyword in KEYWORDS:
    print(f"\n🔍 正在搜索关键词：{keyword}")
    search_url = f"https://api.spotify.com/v1/search?q={keyword}&type=playlist&limit=20"
    resp = requests.get(search_url, headers=HEADERS)
    if resp.status_code != 200:
        print(f"⚠️ 搜索失败：{search_url}")
        print(resp.text)
        continue

    playlists = resp.json().get("playlists", {}).get("items", [])
    print(f"📊 找到歌单数：{len(playlists)}")

    for pl in playlists:
        if not pl or not isinstance(pl, dict):
            continue

        playlist_id = pl.get("id")
        playlist_name = pl.get("name") or ""
        playlist_desc = pl.get("description") or ""
        playlist_url = pl.get("external_urls", {}).get("spotify", "")

        if not playlist_id or not playlist_desc.strip():
            print(f"⚠️ 跳过无效或无描述歌单：{playlist_name}")
            continue

        print(f"🎵 抓取歌单：{playlist_name}")
        playlist_tracks_url = f"https://api.spotify.com/v1/playlists/{playlist_id}/tracks?limit=3"
        track_resp = requests.get(playlist_tracks_url, headers=HEADERS)
        if track_resp.status_code != 200:
            print(f"⚠️ 歌单曲目抓取失败：{playlist_tracks_url}")
            print(track_resp.text)
            continue

        tracks = track_resp.json().get("items", [])
        for item in tracks:
            track_info = item.get("track") if item else {}
            if not track_info or not isinstance(track_info, dict):
                continue

            track_name = track_info.get("name") or ""
            artists = track_info.get("artists") or []
            artist_name = artists[0].get("name") if artists and isinstance(artists[0], dict) else ""
            track_link = track_info.get("external_urls", {}).get("spotify", "")

            if not track_name:
                continue

            data_pairs.append({
                "keyword": keyword,
                "playlist_name": playlist_name,
                "playlist_description": playlist_desc,
                "playlist_url": playlist_url,
                "track_name": track_name,
                "artist": artist_name,
                "track_url": track_link
            })

        time.sleep(1)

# ========== 6. 保存为CSV ==========
df = pd.DataFrame(data_pairs)
df.to_csv("spotify_scene_playlists.csv", index=False, encoding="utf-8-sig")
print("\n✅ 数据抓取完成，保存为 spotify_scene_playlists.csv")
# Out:
# 🔍 正在搜索关键词：restaurant
# 📊 找到歌单数：20
# 🎵 抓取歌单：Restaurant Music 2025
# ⚠️ 跳过无效或无描述歌单：restaurant lounge vibes but in a cool, chill, funky way
# 🎵 抓取歌单：RESTAURANT MUSIC 2025 🍽  chill covers & dinner songs
# ⚠️ 跳过无效或无描述歌单：Upbeat clean restaurant 2.0
# 🎵 抓取歌单：fancy restaurant music
# 🎵 抓取歌单：Restaurant Lounge Music 2025 🍸 Background Music 🍸 Dinner Chill
# ⚠️ 跳过无效或无描述歌单：Clean Restaurant Music 2023 / 2024 (2)
# ⚠️ 跳过无效或无描述歌单：upbeat restaurant music
# 🎵 抓取歌单：Chill Restaurant & Bar Vibes
# 🎵 抓取歌单：Chill restaurant summer🌞
# 🎵 抓取歌单：Dinner Jazz in the Background
# ⚠️ 跳过无效或无描述歌单：90's and 2000's for restaurant
# 🎵 抓取歌单：DINNER JAZZ 🍷 Instrumental Jazz & Bossa Nova (Restaurant Music)
# ⚠️ 跳过无效或无描述歌单：Mexican Restaurant Music
# ⚠️ 跳过无效或无描述歌单：my clean restaraunt playlist
# 🎵 抓取歌单：Restaurant Background Music 🍸 chill covers & saxophone lounge
# ⚠️ 跳过无效或无描述歌单：clean pop, indie, and r&b restaurant hits
#
# 🔍 正在搜索关键词：cafe
# 📊 找到歌单数：20
# 🎵 抓取歌单：Cozy Coffee Shop ☕ Jazz in the Background
# 🎵 抓取歌单：lofi Jazz Cafe 🎷Study Beats & Chill Vibes
# 🎵 抓取歌单：Café Music 2025 ☕ Chill Vibes -  Coffee Lounge - Morning Chill - Relax - Summer Edition
# 🎵 抓取歌单：French Cafe Lounge
# ⚠️ 跳过无效或无描述歌单：LOS EXITOS DE CAFE TACUBA
# 🎵 抓取歌单：happy vibey cafe
# 🎵 抓取歌单：Lofi Coffee Shop (Lo-Fi Café Morning)
# 🎵 抓取歌单：LoFi Cafe | Lofi Jazz Beats & Chill
# ⚠️ 跳过无效或无描述歌单：CAFE TACVBA EXITOS
# ⚠️ 跳过无效或无描述歌单：Caifanes, enanitos verdes, hombres g, jaguares, soda stereo, café tacuba, etc...
# 🎵 抓取歌单：studying at a coffee shop
# 🎵 抓取歌单：soft café jazz (study)
#
# 🔍 正在搜索关键词：coffee shop
# 📊 找到歌单数：20
# 🎵 抓取歌单：Cozy Coffee Shop ☕ Jazz in the Background
# 🎵 抓取歌单：Instrumental Studying 🎻🕊️🎧📑🍵 (soft/no lyrics)
# ⚠️ 跳过无效或无描述歌单：Early 2000s Coffee Shop
# 🎵 抓取歌单：Lofi Coffee Shop (Lo-Fi Café Morning)
# ⚠️ 跳过无效或无描述歌单：Coffee shop playlist☕️🫶🏼
# ⚠️ 跳过无效或无描述歌单：Vibey Coffee Shop
# 🎵 抓取歌单：Café Music 2025 ☕ Chill Vibes -  Coffee Lounge - Morning Chill - Relax - Summer Edition
# 🎵 抓取歌单：Coffee Shop Vibes ☕️
# ⚠️ 跳过无效或无描述歌单：a nice, clean coffee shop playlist☕️✨
# 🎵 抓取歌单：i work at a coffee shop and have to play clean songs
# ⚠️ 跳过无效或无描述歌单：studying in a coffee shop on a rainy day
# ⚠️ 跳过无效或无描述歌单：clean coffee shop jams
#
# 🔍 正在搜索关键词：dining
# 📊 找到歌单数：20
# 🎵 抓取歌单：Fine Dining Music
# 🎵 抓取歌单：SINING - Dionela Jay R
# 🎵 抓取歌单：PIANO COVERS 2025 🎹 relaxing versions of popular songs
# ⚠️ 跳过无效或无描述歌单：dilaw, sining, hoodie, museo, kape, sunset.. ikaw nalang kulang
# 🎵 抓取歌单：fancy restaurant music
# 🎵 抓取歌单：INSTRUMENTAL COVERS 2025 ✨ popular songs
# 🎵 抓取歌单：Dinner Jazz in the Background
# ⚠️ 跳过无效或无描述歌单：Best singing songs
# 🎵 抓取歌单：GUITAR COVERS 2025 💛 Relaxing Versions of Popular Songs
# 🎵 抓取歌单：Marilag - Dionela
# ⚠️ 跳过无效或无描述歌单：Classy Dinner Music
# ⚠️ 跳过无效或无描述歌单：my vocals go HARD
# 🎵 抓取歌单：Dinner Chill Music 🍝🍷 2025
# 🎵 抓取歌单：Sound Bath (10 Hours) Crystal Singing Bowls, Tibetan Bowls, Relaxing Music & Healing Tones
# ⚠️ 跳过无效或无描述歌单：for the dining scene
# ⚠️ 跳过无效或无描述歌单：sining
#
# 🔍 正在搜索关键词：brunch spot
# 📊 找到歌单数：20
# 🎵 抓取歌单：Jazz Brunch Cafe
# 🎵 抓取歌单：Morning Coffee Lo-fi Beats Breakfast Brunch Morning Routine- songs with no words wordless no lyrics
# 🎵 抓取歌单：Brunch Vibes 2025
# 🎵 抓取歌单：Williamsburg Brunch
# 🎵 抓取歌单：Posty 😜
# 🎵 抓取歌单：Brunch Vibes 2025
# ⚠️ 跳过无效或无描述歌单：Brunch Spot
# ⚠️ 跳过无效或无描述歌单：Brunch Cafe Radio
# 🎵 抓取歌单：Sunday Morning Brunch
# ⚠️ 跳过无效或无描述歌单：Brunch Party 🍓🥂
# ⚠️ 跳过无效或无描述歌单：Brunchcore Spotify
# 🎵 抓取歌单：Saint Brunch Ratchet vibes 230-5 pm
# ⚠️ 跳过无效或无描述歌单：Upbeat Brunch Mood ☀️
# 🎵 抓取歌单：Sunday Brunch
# 🎵 抓取歌单：SUNDAY BRUNCH 🥞
# 🎵 抓取歌单：Sunday Brunch 🍽
# ⚠️ 跳过无效或无描述歌单：Sunday Funday Brunch
#
# 🔍 正在搜索关键词：fine dining
# 📊 找到歌单数：20
# 🎵 抓取歌单：Fine Dining Music
# 🎵 抓取歌单：ELEGANT JAZZ 🍷 Instrumental Music for a Fancy Dinner
# 🎵 抓取歌单：fancy restaurant music
# 🎵 抓取歌单：fine dining
# 🎵 抓取歌单：Jazz Instrumental Music - Lounge & Restaurant
# ⚠️ 跳过无效或无描述歌单：Fine Dining Instrumental
# ⚠️ 跳过无效或无描述歌单：Fine Dining Jazz
# 🎵 抓取歌单：Fine dining for home & Restaurant
# ⚠️ 跳过无效或无描述歌单：Fine dining
# 🎵 抓取歌单：Luxury Restaurant Music
# 🎵 抓取歌单：Bossa Nova Restaurant
# ⚠️ 跳过无效或无描述歌单：Fine dining
# ⚠️ 跳过无效或无描述歌单：Fine Dining
# 🎵 抓取歌单：Fine Dining Piano
# ⚠️ 跳过无效或无描述歌单：Fine Dining
# ⚠️ 跳过无效或无描述歌单：Fine Dining Covers
# ⚠️ 跳过无效或无描述歌单：Fine dining
# ⚠️ 跳过无效或无描述歌单：Fine Italian Dining Music
# ⚠️ 跳过无效或无描述歌单：Instrumentals (Fine Dining)
#
# 🔍 正在搜索关键词：bistro
# 📊 找到歌单数：20
# 🎵 抓取歌单：Cafe Bistro Music
# ⚠️ 跳过无效或无描述歌单：French Bistro Music
# ⚠️ 跳过无效或无描述歌单：Bistro huddy playlist😜
# 🎵 抓取歌单：Italian Cafe & Bistro
# ⚠️ 跳过无效或无描述歌单：Bistro Playlist
# ⚠️ 跳过无效或无描述歌单：Bistro Huddy
# 🎵 抓取歌单：FRENCH 🇨🇵 BISTRO
# ⚠️ 跳过无效或无描述歌单：Bistro
# 🎵 抓取歌单：⊱  ۫ ׅ ✧ Nicole | Bistro Huddy
# 🎵 抓取歌单：French Dinner Party
# ⚠️ 跳过无效或无描述歌单：Bistro Patio Playlist
# 🎵 抓取歌单：Restaurant Lounge
# 🎵 抓取歌单：Bistro Lounge Music
# ⚠️ 跳过无效或无描述歌单：The Egg Bistro's Bloody Mary Mix
# 🎵 抓取歌单：Bistro
# 🎵 抓取歌单：𝓐𝓶𝓫𝓮𝓻 𝔁 𝓙𝓸𝓮𝔂
# 🎵 抓取歌单：Le Petit Bistrot , modern French mixed music list for restaurante ( modern fransk spellista ).
# ⚠️ 跳过无效或无描述歌单：Bistro
#
# 🔍 正在搜索关键词：bar
# 📊 找到歌单数：20
# ⚠️ 跳过无效或无描述歌单：BARBIE SONGS OF ALL BARBIE MOVIES
# 🎵 抓取歌单：💗Old barbie Songs💗
# ⚠️ 跳过无效或无描述歌单：Bardcore Covers
# 🎵 抓取歌单：I'M A BARBIE GIRL IN A BARBIE WORLD!
# 🎵 抓取歌单：Early 2000s Barbie songs>>>>>>>>>
# 🎵 抓取歌单：jazz bar in nyc🎷
# 🎵 抓取歌单：BARRY WHITE'S GREATEST HITS.
# ⚠️ 跳过无效或无描述歌单：Top 100 Bar Songs
# 🎵 抓取歌单：lofi Jazz Cafe 🎷Study Beats & Chill Vibes
# ⚠️ 跳过无效或无描述歌单：Barry Manilow – Greatest Hits
# ⚠️ 跳过无效或无描述歌单：Los Alegres Del Barranco corridos
# ⚠️ 跳过无效或无描述歌单：COLLEGE BAR SONGS
#
# 🔍 正在搜索关键词：japanese restaurant
# 📊 找到歌单数：20
# ⚠️ 跳过无效或无描述歌单： Japanese Restaurant Music
# 🎵 抓取歌单：80/90s Japanese City Pop
# 🎵 抓取歌单：Sushi Nights - Japanese Music | Traditional Asian Vibes, Peaceful Instrumental, Guitar, Piano, OSTs
# ⚠️ 跳过无效或无描述歌单：⛩ Japanese Restaurant
# ⚠️ 跳过无效或无描述歌单：JAPANESE DINNER MUSIC
# ⚠️ 跳过无效或无描述歌单：JAPANESE RESTAURANT NINTAI
# 🎵 抓取歌单：Tokyo City Cafe 日本 Coffee Shop
# ⚠️ 跳过无效或无描述歌单：a japanese playlist for the ramen restaurant i worked at
# 🎵 抓取歌单：🌸JAPANESE GARDEN🌸
# 🎵 抓取歌单：Nami playlist !
# 🎵 抓取歌单：Blue Spice Radio
# ⚠️ 跳过无效或无描述歌单：Japanese restaurant song
# 🎵 抓取歌单：70s Japanese Jazz/Funk
# ⚠️ 跳过无效或无描述歌单： japanese restaurant
# 🎵 抓取歌单：Japanese Zen Garden 日本庭園 - Peaceful Instrumental Asian Music for Rest, Relaxation, Meditation & Spa
# 🎵 抓取歌单：Japanese Restaurant At the End Of Time
# 🎵 抓取歌单：JAPANESE TRADITIONAL MUSIC
#
# 🔍 正在搜索关键词：sushi bar
# 📊 找到歌单数：20
# 🎵 抓取歌单：Sushi Nights - Japanese Music | Traditional Asian Vibes, Peaceful Instrumental, Guitar, Piano, OSTs
# 🎵 抓取歌单：Sushi Lounge 🍣 Chill Background Music
# 🎵 抓取歌单：Sushi Lounge Restaurant
# 🎵 抓取歌单：Restaurant Lounge Music 🍝🍷🍴 Dinner Chill 2025
# 🎵 抓取歌单：Sushi-bar Speakeasy 🎏
# ⚠️ 跳过无效或无描述歌单：Sushi Bar Playlist
# ⚠️ 跳过无效或无描述歌单：Sushi bar Miami  #2
# ⚠️ 跳过无效或无描述歌单：Sushi Bar Music
# ⚠️ 跳过无效或无描述歌单：Matsu sushi bar
# 🎵 抓取歌单：music for a sushi restaurant vibes
# ⚠️ 跳过无效或无描述歌单：Sushi Bar Mon-Friday
# ⚠️ 跳过无效或无描述歌单： Japanese Restaurant Music
# 🎵 抓取歌单：jazz bar in nyc🎷
# ⚠️ 跳过无效或无描述歌单：SVB - Sushi Bar v2 (Jack Johnson & Co)
# ⚠️ 跳过无效或无描述歌单：Music For a Sushi Restaurant
# ⚠️ 跳过无效或无描述歌单：Sushi Bar
# ⚠️ 跳过无效或无描述歌单：sushi restaurant
# ⚠️ 跳过无效或无描述歌单：Sushi Dinner Party
#
# 🔍 正在搜索关键词：izakaya
# 📊 找到歌单数：19
# 🎵 抓取歌单：Japanese Izakaya Sake Bar
# 🎵 抓取歌单：Japanese bangers 🇯🇵
# ⚠️ 跳过无效或无描述歌单：Izakaya1
# ⚠️ 跳过无效或无描述歌单：japanese izakaya feels
# ⚠️ 跳过无效或无描述歌单：Lan izakaya hh
# ⚠️ 跳过无效或无描述歌单：izakaya
# ⚠️ 跳过无效或无描述歌单：Izakaya🏮
# ⚠️ 跳过无效或无描述歌单：Izakaya RINGO
# 🎵 抓取歌单：Izakaya Japanese Cuisine
# ⚠️ 跳过无效或无描述歌单：Japanese Izakaya Dinner vibe
# ⚠️ 跳过无效或无描述歌单：Izakaya hip-hop
# ⚠️ 跳过无效或无描述歌单：Japanese Izakaya Lunch vibe
# 🎵 抓取歌单：Izakaya Nights : jazz hop
# ⚠️ 跳过无效或无描述歌单：216izakaya
# ⚠️ 跳过无效或无描述歌单：Reiwa Izakaya
# ⚠️ 跳过无效或无描述歌单：Izakaya Ichie(J-pop)
# 🎵 抓取歌单：Tatsu Izakaya 🏮
# ⚠️ 跳过无效或无描述歌单：Sozai Izakaya
# 🎵 抓取歌单：80/90s Japanese City Pop
#
# 🔍 正在搜索关键词：chinese restaurant
# 📊 找到歌单数：20
# ⚠️ 跳过无效或无描述歌单：Chinese restaurant music
# ⚠️ 跳过无效或无描述歌单：Chinese restaurant music
# 🎵 抓取歌单：Traditional Chinese music • 中國傳統音樂 • 繁体字中国語の音楽
# ⚠️ 跳过无效或无描述歌单：Chinese Buffet
# 🎵 抓取歌单：Chinese restaurant
# 🎵 抓取歌单：Best Chinese Songs of all time
# ⚠️ 跳过无效或无描述歌单：Chinese Restaurant Music
# ⚠️ 跳过无效或无描述歌单：Chinese Restaurant Music
# ⚠️ 跳过无效或无描述歌单： Japanese Restaurant Music
# 🎵 抓取歌单：P.F. Chang's
# ⚠️ 跳过无效或无描述歌单：Chinese Restaurant tracks
# 🎵 抓取歌单：Lofi Chinese Restaurant
# ⚠️ 跳过无效或无描述歌单：above the chinese restaurant 🤙🏽
# ⚠️ 跳过无效或无描述歌单：Traditional Chinese Instrumental
# 华语榜 2025
# ⚠️ 跳过无效或无描述歌单：Restaurant Chinese Songs
#
# 🔍 正在搜索关键词：hotpot
# 📊 找到歌单数：20
# 🎵 抓取歌单：HOTPOT MUSIC 🍲
# 🎵 抓取歌单：Ur best Viet playlist
# ⚠️ 跳过无效或无描述歌单：hotpot
# ⚠️ 跳过无效或无描述歌单：Music to eat hotpot to
# ⚠️ 跳过无效或无描述歌单：hotpot
# ⚠️ 跳过无效或无描述歌单：Hotpot Chinese / Japanese  Music Lofi Style
# ⚠️ 跳过无效或无描述歌单：Hotpot
# 🎵 抓取歌单：最爱...火锅 - SHILIFANG HOTPOT PLAYLIST
# 🎵 抓取歌单：2018年串烧 reel
# ⚠️ 跳过无效或无描述歌单：HotPot
# ⚠️ 跳过无效或无描述歌单：Hotpot Playlist
# ⚠️ 跳过无效或无描述歌单：Hotpot Jams
# ⚠️ 跳过无效或无描述歌单：Hot pot
# ⚠️ 跳过无效或无描述歌单：Chinese restaurant music
# 🎵 抓取歌单：You know that I'm the girl that you should call
# ⚠️ 跳过无效或无描述歌单：Hot Potato Songs
# ⚠️ 跳过无效或无描述歌单：hotpot
#
# 🔍 正在搜索关键词：dim sum
# 📊 找到歌单数：20
# ⚠️ 跳过无效或无描述歌单：Dim Sum
# 🎵 抓取歌单：The 5th Dimension: Greatest Hits
# ⚠️ 跳过无效或无描述歌单：Dim Sum music
# 🎵 抓取歌单：Greek Summer Mix 2025
# ⚠️ 跳过无效或无描述歌单：Dim Sum Yum Yum
# ⚠️ 跳过无效或无描述歌单：Shake sum ass🍑❤️💕
# ⚠️ 跳过无效或无描述歌单：Yum Yum Dim Sum
# 🎵 抓取歌单：Ibiza Summer Mix 2025 TOP  100🌴 Sunset Vibes Deep House Afro House Party Lounge Chill Soft House
# 🎵 抓取歌单：Summer of Soul: Soundtrack + Festival
# ⚠️ 跳过无效或无描述歌单：Greenday, Sum 41, Simple Plan, Blink 182 by : DIMSFREAKS
# ⚠️ 跳过无效或无描述歌单：BLICK SUM
# ⚠️ 跳过无效或无描述歌单：Asian remixes
# 🎵 抓取歌单：kbbq🔥
# ⚠️ 跳过无效或无描述歌单：Chinese Buffet
# ⚠️ 跳过无效或无描述歌单：Dim Sum and Ditties
#
# 🔍 正在搜索关键词：korean bbq
# 📊 找到歌单数：20
# ⚠️ 跳过无效或无描述歌单：Korean bbq dinner music
# 🎵 抓取歌单：Late Night Korean BBQ
# 🎵 抓取歌单：Gen Korean BBQ Carrollton Hip Hop/R&B
# 🎵 抓取歌单：Korean BBQ Playlist
# 🎵 抓取歌单：K-BBQ - 고기구이
# 🎵 抓取歌单：korean bbq
# ⚠️ 跳过无效或无描述歌单：Korean BBQ House Music
# 🎵 抓取歌单：Korean Cafe Vibes 🫰
# ⚠️ 跳过无效或无描述歌单：korean bbq
# ⚠️ 跳过无效或无描述歌单：Korean BBQ
# ⚠️ 跳过无效或无描述歌单：Why is the korean BBQ not spicy?
# ⚠️ 跳过无效或无描述歌单：Korean R&B 🪴🎵
# ⚠️ 跳过无效或无描述歌单：Asian Trap, Asian Beats 🐉
# ⚠️ 跳过无效或无描述歌单：Korean BBQ
# ⚠️ 跳过无效或无描述歌单：Korean bbq
#
# 🔍 正在搜索关键词：french restaurant
# 📊 找到歌单数：20
# 🎵 抓取歌单：French Café Lounge
# 🎵 抓取歌单：French Cafe Lounge
# 🎵 抓取歌单：fancy restaurant music
# 🎵 抓取歌单：Le Petit Bistrot , modern French mixed music list for restaurante ( modern fransk spellista ).
# ⚠️ 跳过无效或无描述歌单：French music for restaurant
# ⚠️ 跳过无效或无描述歌单：fancy french restaurant
# 🎵 抓取歌单：Paris Café Songs ☕
# 🎵 抓取歌单：Vintage French Music
# 🎵 抓取歌单：Best of Lana Del Rey + unreleased
# 🎵 抓取歌单：lana unreleased 🎀
# 🎵 抓取歌单：FRENCH RESTAURANT
# ⚠️ 跳过无效或无描述歌单：French café instrumental
# ⚠️ 跳过无效或无描述歌单：French Restaurant Hits
# ⚠️ 跳过无效或无描述歌单：French Bistro Music
# 🎵 抓取歌单：Côte D'Azur Chill & Relax Café
# 🎵 抓取歌单：French Yves-ning
# 🎵 抓取歌单：Ratatouille cooking vibes
#
# 🔍 正在搜索关键词：italian restaurant
# 📊 找到歌单数：20
# ⚠️ 跳过无效或无描述歌单：Italian Restaurant Classics
# 🎵 抓取歌单：Italian Restaurant Instrumental Music
# ⚠️ 跳过无效或无描述歌单：Italian Cooking Music
# ⚠️ 跳过无效或无描述歌单：Old Italian classics🇮🇹
# 🎵 抓取歌单：Italian restaurant 🇮🇹 | musica soft Ristorante italiano | background music for dinner / lunch
# ⚠️ 跳过无效或无描述歌单：Italian Restaurant Lounge Music (The best Italian Songs to relax for your lunch or dinner)
# 🎵 抓取歌单：Italian Dinner Music
# 🎵 抓取歌单：fancy italian restaurant
# ⚠️ 跳过无效或无描述歌单：Italian Café Jazz
# 🎵 抓取歌单：Italian Dinner Music - Italian Cooking Music - made by an  Italian!
# ⚠️ 跳过无效或无描述歌单：Italian Dinner Instrumental Only
# 🎵 抓取歌单：Italian Cafe & Bistro
# 🎵 抓取歌单：Italian Music Restaurant
# ⚠️ 跳过无效或无描述歌单：happy italian dinner music
# 🎵 抓取歌单：Best Italian Restaurant Music - Jazz, Lounge, Happy Hour
# 🎵 抓取歌单：Italian Mafia Music
# 🎵 抓取歌单：Italian Restaurant Music
#
# 🔍 正在搜索关键词：mexican restaurant
# 📊 找到歌单数：20
# ⚠️ 跳过无效或无描述歌单：Mexican Restaurant Music
# ⚠️ 跳过无效或无描述歌单：Mexican Restaurant Vibes
# ⚠️ 跳过无效或无描述歌单：Música para restaurante mexicano🌵🤠
# 🎵 抓取歌单：Mexican Party Bangerz
# ⚠️ 跳过无效或无描述歌单：TACO TUESDAY
# ⚠️ 跳过无效或无描述歌单：Restaurante Mexicano
# 🎵 抓取歌单：drunk mexican dad music
# ⚠️ 跳过无效或无描述歌单：Traditional Mexican Music
# 🎵 抓取歌单：Restaurante Mexicano 🇲🇽 🎉
# ⚠️ 跳过无效或无描述歌单：Mexican Restaurant background
# ⚠️ 跳过无效或无描述歌单：Musica mexicana restaurante
# 🎵 抓取歌单：BEST MEXICAN HITS 🇲🇽
# ⚠️ 跳过无效或无描述歌单：Mix para Restaurante Mexicano
# ⚠️ 跳过无效或无描述歌单：mexican mom cleaning music 🧼 🧹
# 🎵 抓取歌单：when you work at a mexican restaurant
# ⚠️ 跳过无效或无描述歌单：Dad’s old mexican songs
# ⚠️ 跳过无效或无描述歌单：Mexico resort vibes🇲🇽
# 🎵 抓取歌单：Mexican Restaurant Con Sabor
#
# 🔍 正在搜索关键词：indian restaurant
# 📊 找到歌单数：20
# ⚠️ 跳过无效或无描述歌单：Indian Restaurant Music
# 🎵 抓取歌单：Indian Restaurant
# 🎵 抓取歌单：Bombay Mahal
# ⚠️ 跳过无效或无描述歌单：Indian meme music
# ⚠️ 跳过无效或无描述歌单：Indian Restaurant Music
# ⚠️ 跳过无效或无描述歌单：Famous Indian Song
# ⚠️ 跳过无效或无描述歌单：Indian Restaurant Bollywood Soothing Mix Songs
# ⚠️ 跳过无效或无描述歌单：Indian restaurant
# 🎵 抓取歌单：Indian Traditional Music
# 🎵 抓取歌单：Indian Restaurant Music
# ⚠️ 跳过无效或无描述歌单：INDIAN PARTY HITS
# ⚠️ 跳过无效或无描述歌单：Music for an Indian Restaurant
# 🎵 抓取歌单：MAZU Restaurant Playlist
# ⚠️ 跳过无效或无描述歌单：Mexican Restaurant Music
# ⚠️ 跳过无效或无描述歌单：on aux at indian restaurant in gambia
# 🎵 抓取歌单：Bollywood indian restaurant
# 🎵 抓取歌单：Bollywood Vibe Playlist for Indian Restaurant
#
# 🔍 正在搜索关键词：vegan cafe
# 📊 找到歌单数：20
# ⚠️ 跳过无效或无描述歌单：vegan cafe
# 🎵 抓取歌单：clean cafe vibes ☕️🌱🌊
# 🎵 抓取歌单：Alt-Crunchy: Neo-Hippie, Jam Band, and Folky Vibes 1992-1998
# 🎵 抓取歌单：happy vibey cafe
# ⚠️ 跳过无效或无描述歌单：our dream vegan cafe
# ⚠️ 跳过无效或无描述歌单：Vibey Coffee Shop
# 🎵 抓取歌单：senorita awesome
# ⚠️ 跳过无效或无描述歌单：Vegan Vegentarian
# ⚠️ 跳过无效或无描述歌单：Café con Vegan Leche
# ⚠️ 跳过无效或无描述歌单：Happy cafe music
# 🎵 抓取歌单：Upbeat Cafe Mix
# ⚠️ 跳过无效或无描述歌单：clean cafe/shop music ☕️
# 🎵 抓取歌单：HAPPY CAFE MUSIC
# 🎵 抓取歌单：clean happy cafe music ☕️
# 🎵 抓取歌单：vibey coffee shop
#
# ✅ 数据抓取完成，保存为 spotify_scene_playlists.csv
